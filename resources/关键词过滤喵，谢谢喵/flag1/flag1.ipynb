# %%
import re 
re0 = re.compile('[\S\s]')
s = '1' * 79
len(s)
# Out:
# 79

# %%
s = re0.sub('a', s)

sb = re.compile('a{10}')
sc = re.compile('b{10}')
sd = re.compile('c{10}')
se = re.compile('d{10}')
sf = re.compile('e{10}')

s = sb.sub('b', s)
s = sc.sub('c', s)
s = sd.sub('d', s)
s = se.sub('e', s)
s = sf.sub('f', s)

s
# Out:
# 'bbbbbbbaaaaaaaaa'

# %%
sf0 = re.compile('f$')
sfa = re.compile('fa')
sfb = re.compile('fb')
sfc = re.compile('fc')
sfd = re.compile('fd')

s = sf0.sub('f00000', s)
s = sfa.sub('f0000a', s)
s = sfb.sub('f000b', s)
s = sfc.sub('f00c', s)
s = sfd.sub('f0d', s)

se0 = re.compile('e$')
sea = re.compile('ea')
seb = re.compile('eb')
sec = re.compile('ec')

s = se0.sub('e0000', s)
s = sea.sub('e000a', s)
s = seb.sub('e00b', s)
s = sec.sub('e0c', s)

sd0 = re.compile('d$')
sda = re.compile('da')
sdb = re.compile('db')

s = sd0.sub('d000', s)
s = sda.sub('d00a', s)
s = sdb.sub('d0b', s)

sc0 = re.compile('c$')
sca = re.compile('ca')

s = sc0.sub('c00', s)
s = sca.sub('c0a', s)

sb0 = re.compile('b$')

s = sb0.sub('b0', s)

s
# Out:
# 'bbbbbbbaaaaaaaaa'

# %%
def f(s):

    resp = re.compile('^$')
    if (resp.search(s)):
        s = resp.sub('0', s)
        return s

    re0 = re.compile('[\S\s]')
    s = re0.sub('a', s)

    sb = re.compile('a{10}')
    sc = re.compile('b{10}')
    sd = re.compile('c{10}')
    se = re.compile('d{10}')
    sf = re.compile('e{10}')

    s = sb.sub('b', s)
    s = sc.sub('c', s)
    s = sd.sub('d', s)
    s = se.sub('e', s)
    s = sf.sub('f', s)

    sf0 = re.compile('f$')
    sfa = re.compile('fa')
    sfb = re.compile('fb')
    sfc = re.compile('fc')
    sfd = re.compile('fd')

    s = sf0.sub('f00000', s)
    s = sfa.sub('f0000a', s)
    s = sfb.sub('f000b', s)
    s = sfc.sub('f00c', s)
    s = sfd.sub('f0d', s)

    se0 = re.compile('e$')
    sea = re.compile('ea')
    seb = re.compile('eb')
    sec = re.compile('ec')

    s = se0.sub('e0000', s)
    s = sea.sub('e000a', s)
    s = seb.sub('e00b', s)
    s = sec.sub('e0c', s)

    sd0 = re.compile('d$')
    sda = re.compile('da')
    sdb = re.compile('db')

    s = sd0.sub('d000', s)
    s = sda.sub('d00a', s)
    s = sdb.sub('d0b', s)

    sc0 = re.compile('c$')
    sca = re.compile('ca')

    s = sc0.sub('c00', s)
    s = sca.sub('c0a', s)

    sb0 = re.compile('b$')

    s = sb0.sub('b0', s)
    
    recount9 = re.compile('[a]{9}')
    recount8 = re.compile('[a]{8}')
    recount7 = re.compile('[a]{7}')
    recount6 = re.compile('[a]{6}')
    recount5 = re.compile('[a]{5}')
    recount4 = re.compile('[a]{4}')
    recount3 = re.compile('[a]{3}')
    recount2 = re.compile('[a]{2}')
    recount1 = re.compile('[a]{1}')

    s = recount9.sub('9', s)
    s = recount8.sub('8', s)
    s = recount7.sub('7', s)
    s = recount6.sub('6', s)
    s = recount5.sub('5', s)
    s = recount4.sub('4', s)
    s = recount3.sub('3', s)
    s = recount2.sub('2', s)
    s = recount1.sub('1', s)

    recount9 = re.compile('[b]{9}')
    recount8 = re.compile('[b]{8}')
    recount7 = re.compile('[b]{7}')
    recount6 = re.compile('[b]{6}')
    recount5 = re.compile('[b]{5}')
    recount4 = re.compile('[b]{4}')
    recount3 = re.compile('[b]{3}')
    recount2 = re.compile('[b]{2}')
    recount1 = re.compile('[b]{1}')

    s = recount9.sub('9', s)
    s = recount8.sub('8', s)
    s = recount7.sub('7', s)
    s = recount6.sub('6', s)
    s = recount5.sub('5', s)
    s = recount4.sub('4', s)
    s = recount3.sub('3', s)
    s = recount2.sub('2', s)
    s = recount1.sub('1', s)

    recount9 = re.compile('[c]{9}')
    recount8 = re.compile('[c]{8}')
    recount7 = re.compile('[c]{7}')
    recount6 = re.compile('[c]{6}')
    recount5 = re.compile('[c]{5}')
    recount4 = re.compile('[c]{4}')
    recount3 = re.compile('[c]{3}')
    recount2 = re.compile('[c]{2}')
    recount1 = re.compile('[c]{1}')

    s = recount9.sub('9', s)
    s = recount8.sub('8', s)
    s = recount7.sub('7', s)
    s = recount6.sub('6', s)
    s = recount5.sub('5', s)
    s = recount4.sub('4', s)
    s = recount3.sub('3', s)
    s = recount2.sub('2', s)
    s = recount1.sub('1', s)

    recount9 = re.compile('[d]{9}')
    recount8 = re.compile('[d]{8}')
    recount7 = re.compile('[d]{7}')
    recount6 = re.compile('[d]{6}')
    recount5 = re.compile('[d]{5}')
    recount4 = re.compile('[d]{4}')
    recount3 = re.compile('[d]{3}')
    recount2 = re.compile('[d]{2}')
    recount1 = re.compile('[d]{1}')

    s = recount9.sub('9', s)
    s = recount8.sub('8', s)
    s = recount7.sub('7', s)
    s = recount6.sub('6', s)
    s = recount5.sub('5', s)
    s = recount4.sub('4', s)
    s = recount3.sub('3', s)
    s = recount2.sub('2', s)
    s = recount1.sub('1', s)

    recount9 = re.compile('[e]{9}')
    recount8 = re.compile('[e]{8}')
    recount7 = re.compile('[e]{7}')
    recount6 = re.compile('[e]{6}')
    recount5 = re.compile('[e]{5}')
    recount4 = re.compile('[e]{4}')
    recount3 = re.compile('[e]{3}')
    recount2 = re.compile('[e]{2}')
    recount1 = re.compile('[e]{1}')

    s = recount9.sub('9', s)
    s = recount8.sub('8', s)
    s = recount7.sub('7', s)
    s = recount6.sub('6', s)
    s = recount5.sub('5', s)
    s = recount4.sub('4', s)
    s = recount3.sub('3', s)
    s = recount2.sub('2', s)
    s = recount1.sub('1', s)

    recount9 = re.compile('[f]{9}')
    recount8 = re.compile('[f]{8}')
    recount7 = re.compile('[f]{7}')
    recount6 = re.compile('[f]{6}')
    recount5 = re.compile('[f]{5}')
    recount4 = re.compile('[f]{4}')
    recount3 = re.compile('[f]{3}')
    recount2 = re.compile('[f]{2}')
    recount1 = re.compile('[f]{1}')

    s = recount9.sub('9', s)
    s = recount8.sub('8', s)
    s = recount7.sub('7', s)
    s = recount6.sub('6', s)
    s = recount5.sub('5', s)
    s = recount4.sub('4', s)
    s = recount3.sub('3', s)
    s = recount2.sub('2', s)
    s = recount1.sub('1', s)


    return s

# %%
from tqdm import tqdm
for i in tqdm(range(8000)):
    if f('.'*i) != str(i):
        print(i)
# Out:
# 100%|██████████| 8000/8000 [00:03<00:00, 2258.48it/s]
